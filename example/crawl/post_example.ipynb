# %%
# -*- coding: utf-8 -*-
import requests
from bs4 import BeautifulSoup

payload = {
"FromStationName":"1008",
"ToStationName":"1025",
"TrainClass":"2",
"searchdate":"2017-12-06",
"FromTimeSelect":"0000",
"ToTimeSelect":"2359",
"Timetype":"1"
}

# %%
response = requests.post('http://twtraffic.tra.gov.tw/twrail/TW_SearchResult.aspx', data=payload)
response.encoding = 'utf-8'

# %%
soup = BeautifulSoup(response.text, 'html.parser')
train_info = soup.find_all('script')
print(train_info)
# Out:
# [<script src="https://code.jquery.com/jquery-1.10.2.min.js"></script>, <script src="//code.jquery.com/ui/1.11.4/jquery-ui.js"></script>, <script src="http://cdn.staticfile.org/moment.js/2.2.1/moment.min.js"></script>, <script src="js/pikaday.js" type="text/javascript"></script>, <script src="js/10607/commonlib.js" type="text/javascript"></script>, <script src="js/kickstart.js" type="text/javascript"></script>, <script>
#     (function (i, s, o, g, r, a, m) {
#         i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#             (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date(); a = s.createElement(o),
#         m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#     })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#     var UAid = "UA-90671200-8";
#     ga('create', UAid, 'auto');
#     ga('require', 'linkid', 'linkid.js');
#     ga('send', 'pageview');
#
#
# 	var uagent = navigator.userAgent.toLowerCase();
#     var language = "tw";
#     var stationdata = new Array();
#     var stationcodedata = new Array();
#
#     setCalendarLanguage();
#
#     //getStation();
#
#     $(document).ready(function () {
#         var pickertop = new Pikaday(
#         {
#             field: document.getElementById('datepickertop'),
#             firstDay: firstdayobj,
#             minDate: new Date(today.getFullYear(), today.getMonth(), today.getDate()),
#             maxDate: new Date(endday.getFullYear(), endday.getMonth(), endday.getDate()),
#             yearRange: [today.getFullYear(), endday.getFullYear()],
#             i18n: calendarobj,
#         });
#
#         getStation();
#
#         $("#TopFromStation").autocomplete({
#             source: stationdata
#         });
#         $("#TopToStation").autocomplete({
#             source: stationdata
#         });
#
#
#         $("#easysearchbtn").click(function () {
#             if (!checkSearchInput("TopFromStation", "TopToStation")) {
#                 alert("請輸入欲查詢之資料!");
#                 return false;
#             }
#         });
#
#
#         $("#datepickertop").val(today.getFullYear() + "-" + padLeft((today.getMonth() + 1), '2') + "-" + padLeft(today.getDate(), '2'));
#
#         showslideimg();
#     });
#
#
#
#
#     var myIndex = 0;
#     var x = document.getElementsByClassName("slideshowimg");
#     //carouselxx();
#     var i;
#     function showslideimg() {
#
#         for (i = 0; i < x.length; i++) {
#             x[i].style.display = "none";
#         }
#         myIndex++;
#         if (myIndex > x.length) { myIndex = 1 }
#         x[myIndex - 1].style.display = "block";
# 		if(/safari/.test(uagent) && !/chrome/.test(uagent))
# 		{
# 			x[myIndex - 1].style.left = "308px";
# 		}
#         //setTimeout(carouselxx, 2000); // Change image every 2 seconds
#     }
#
#     timer2 = setInterval(showslideimg, 5000);
#
#
#
#
#     $(function () {
#         // 先取得 .abgne-news-scroll ul 及 li 的高度
#         // 並設定訊息移動, 淡入及輪播時間
#         var $news = $('.abgne-news-scroll ul'),
# 			scrollHeight = $news.find('li').outerHeight(true),
# 			scrollSpeed = 400, fadeInSpeed = 400,
# 			timer, speed = 6000;
#
#         // 用來控制輪播用
#         function newsScroll() {
#             // 先把 .abgne-news-scroll ul 往下移
#             $news.animate({
#                 top: scrollHeight + 'px'
#             }, scrollSpeed, function () {
#                 // 當 .abgne-news-scroll ul 移動到定點後
#                 // 先找出最後一個 li
#                 var $last = $news.find('li:last');
#                 // 複製一份並先隱藏起來
#                 // 接著把它加到 .abgne-news-scroll ul 中的第一個項目
#                 // 最後用淡入的方式顯示, 當顯示完後繼續輪播
#                 $last.clone().hide().prependTo($news).fadeIn(fadeInSpeed, function () {
#                     timer = setTimeout(newsScroll, speed);
#                 });
#                 // 馬上把 .abgne-news-scroll ul 移到 top 等於 0 的位置
#                 $news.css('top', 0);
#                 // 把 $last 移除掉
#                 $last.remove();
#             });
#         }
#
#         function newsScroll1() {
#             // 先把 .abgne-news-scroll ul 往下移
#             $news.animate({
#                 bottom: scrollHeight + 'px'
#             }, scrollSpeed, function () {
#                 // 當 .abgne-news-scroll ul 移動到定點後
#                 // 先找出最後一個 li
#                 var $first = $news.find('li:first');
#                 // 複製一份並先隱藏起來
#                 // 接著把它加到 .abgne-news-scroll ul 中的第一個項目
#                 // 最後用淡入的方式顯示, 當顯示完後繼續輪播
#                 $first.clone().hide().appendTo($news).fadeIn(fadeInSpeed, function () {
#                     timer = setTimeout(newsScroll, speed);
#                 });
#                 // 馬上把 .abgne-news-scroll ul 移到 top 等於 0 的位置
#                 $news.css('top', 0);
#                 // 把 $last 移除掉
#                 $first.remove();
#             });
#         }
#         // 啟動輪播計時器
#         timer = setTimeout(newsScroll, speed);
#     });
#
#     function openpop() {
#         $("#dialog-modal").dialog({
#             width: 640,
#             height: 480,
#             modal: true,
#             moveToTop: true,
#         });
#     }
#
#     function openpopmsg(msgid) {
#
#         var postData = { datatype: "bulletin", bulletincode: msgid };
#         var accessorise;
#         $.ajax({
#             url: "./Services/BaseDataServ.ashx",
#             type: "post",
#             data: postData,
#             success: function (data) {
#                 jsonStation = $.parseJSON(data);
#                 $.each(jsonStation, function (i, item) {
#                     accessorise = item.Accessorise;
#                     if (accessorise != '')
#                     {
#                         accessorise = "<br/><br/>附加檔案:<br/><a href='http://163.29.3.100/TWRail_Server/new_annouce/UpFiles/" + item.Accessorise + "'  >" + item.Accessorise + "</a>";
#                     }
#
#                     $("#dialog-pop").html(item.Bulletin_Content.replace(/\r?\n/g, "<br/>") + accessorise  );
#
#
#
#                 });
#
#                 $("#dialog-pop").dialog({
#                     width: 640,
#                     height: 480,
#                     modal: true,
#                     moveToTop: true,
#                 });
#
#             }
#         });
#
#
#     }
#
# </script>, <script src="./js/10608/trsearchresult.js" type="text/javascript"></script>, <script src="./js/transfer.js" type="text/javascript"></script>, <script src="./js/10608/filter.js" type="text/javascript"></script>, <script>var QueryData='1008;1025;2;2017-12-06;0000;2359;1';</script>, <script>var JSONData=[
#   {
#     "Train_Code": "1543",
#     "Class_Code": "1132",
#     "Begin_Code": "1006",
#     "Begin_Name": "南港",
#     "Begin_EName": "Nangang",
#     "End_Code": "1207",
#     "End_Name": "二水",
#     "End_EName": "Ershui",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "

#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "2233",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1120",
#     "End_Name": "彰化",
#     "End_EName": "Changhua",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1646",
#     "To_Arrival_Time": "1824",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "139",
#     "Class_Code": "1108",
#     "Begin_Code": "1003",
#     "Begin_Name": "七堵",
#     "Begin_EName": "Qidu",
#     "End_Code": "1411",
#     "End_Name": "潮州",
#     "End_EName": "Chaozhou",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "Y",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1700",
#     "To_Arrival_Time": "1808",
#     "Fare": 177,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1221",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1305",
#     "End_Name": "苗栗",
#     "End_EName": "Miaoli",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1704",
#     "To_Arrival_Time": "1835",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1525",
#     "Class_Code": "1132",
#     "Begin_Code": "1003",
#     "Begin_Name": "七堵",
#     "Begin_EName": "Qidu",
#     "End_Code": "1120",
#     "End_Name": "彰化",
#     "End_EName": "Changhua",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "2",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1712",
#     "To_Arrival_Time": "1848",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1223",
#     "Class_Code": "1131",
#     "Begin_Code": "1804",
#     "Begin_Name": "瑞芳",
#     "Begin_EName": "Ruifang",
#     "End_Code": "1305",
#     "End_Name": "苗栗",
#     "End_EName": "Miaoli",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1716",
#     "To_Arrival_Time": "1853",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "141",
#     "Class_Code": "1108",
#     "Begin_Code": "1003",
#     "Begin_Name": "七堵",
#     "Begin_EName": "Qidu",
#     "End_Code": "1411",
#     "End_Name": "潮州",
#     "End_EName": "Chaozhou",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "Y",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1730",
#     "To_Arrival_Time": "1838",
#     "Fare": 177,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1227",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1025",
#     "End_Name": "新竹",
#     "End_EName": "Hsinchu",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "0",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1735",
#     "To_Arrival_Time": "1912",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "177",
#     "Class_Code": "1108",
#     "Begin_Code": "1715",
#     "Begin_Name": "花蓮",
#     "Begin_EName": "Hualien",
#     "End_Code": "1211",
#     "End_Name": "斗南",
#     "End_EName": "Dounan",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "Y",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1745",
#     "To_Arrival_Time": "1903",
#     "Fare": 177,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1229",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1025",
#     "End_Name": "新竹",
#     "End_EName": "Hsinchu",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "0",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1755",
#     "To_Arrival_Time": "1936",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1231",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1025",
#     "End_Name": "新竹",
#     "End_EName": "Hsinchu",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "0",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1804",
#     "To_Arrival_Time": "1942",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "145",
#     "Class_Code": "1108",
#     "Begin_Code": "1003",
#     "Begin_Name": "七堵",
#     "Begin_EName": "Qidu",
#     "End_Code": "1411",
#     "End_Name": "潮州",
#     "End_EName": "Chaozhou",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "Y",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1810",
#     "To_Arrival_Time": "1918",
#     "Fare": 177,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1033",
#     "Class_Code": "1131",
#     "Begin_Code": "1005",
#     "Begin_Name": "汐止",
#     "Begin_EName": "Xizhi",
#     "End_Code": "1028",
#     "End_Name": "竹南",
#     "End_EName": "Zhunan",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "0",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1819",
#     "To_Arrival_Time": "2002",
#     "Fare": 114,
#     "Comment": "逢週一至五行駛。區間車(長編組)",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "N",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "147",
#     "Class_Code": "1108",
#     "Begin_Code": "1003",
#     "Begin_Name": "七堵",
#     "Begin_EName": "Qidu",
#     "End_Code": "1028",
#     "End_Name": "竹南",
#     "End_EName": "Zhunan",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "0",
#     "Handicapped": "Y",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1833",
#     "To_Arrival_Time": "1947",
#     "Fare": 177,
#     "Comment": "逢週五停駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "N",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "2253",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1215",
#     "End_Name": "嘉義",
#     "End_EName": "Chiayi",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1837",
#     "To_Arrival_Time": "2014",
#     "Fare": 114,
#     "Comment": "逢週日停駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "N",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "149",
#     "Class_Code": "1108",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1411",
#     "End_Name": "潮州",
#     "End_EName": "Chaozhou",
#     "Over_Night": "1406",
#     "Direction": "1",
#     "MainViaRoad": "2",
#     "Handicapped": "Y",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1845",
#     "To_Arrival_Time": "1954",
#     "Fare": 177,
#     "Comment": "每日行駛。在屏東跨日。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1233",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1305",
#     "End_Name": "苗栗",
#     "End_EName": "Miaoli",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1850",
#     "To_Arrival_Time": "2023",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "653",
#     "Class_Code": "1111",
#     "Begin_Code": "1632",
#     "Begin_Name": "臺東",
#     "Begin_EName": "Taitung",
#     "End_Code": "1120",
#     "End_Name": "彰化",
#     "End_EName": "Changhua",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "2",
#     "Handicapped": "Y",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1904",
#     "To_Arrival_Time": "2040",
#     "Fare": 137,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1241",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1025",
#     "End_Name": "新竹",
#     "End_EName": "Hsinchu",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "0",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1914",
#     "To_Arrival_Time": "2053",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "181",
#     "Class_Code": "1108",
#     "Begin_Code": "1715",
#     "Begin_Name": "花蓮",
#     "Begin_EName": "Hualien",
#     "End_Code": "1411",
#     "End_Name": "潮州",
#     "End_EName": "Chaozhou",
#     "Over_Night": "1242",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "Y",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1926",
#     "To_Arrival_Time": "2035",
#     "Fare": 177,
#     "Comment": "每日行駛。在新左營跨日。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1243",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1025",
#     "End_Name": "新竹",
#     "End_EName": "Hsinchu",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "0",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1930",
#     "To_Arrival_Time": "2114",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1247",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1305",
#     "End_Name": "苗栗",
#     "End_EName": "Miaoli",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1949",
#     "To_Arrival_Time": "2127",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "2269",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1207",
#     "End_Name": "二水",
#     "End_EName": "Ershui",
#     "Over_Night": "1203",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "1958",
#     "To_Arrival_Time": "2143",
#     "Fare": 114,
#     "Comment": "每日行駛。在員林跨日。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "283",
#     "Class_Code": "1107",
#     "Begin_Code": "1606",
#     "Begin_Name": "壽豐",
#     "Begin_EName": "Shoufeng",
#     "End_Code": "1210",
#     "End_Name": "斗六",
#     "End_EName": "Douliu",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "Y",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "2015",
#     "To_Arrival_Time": "2104",
#     "Fare": 177,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1251",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1025",
#     "End_Name": "新竹",
#     "End_EName": "Hsinchu",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "0",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "2025",
#     "To_Arrival_Time": "2204",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "285",
#     "Class_Code": "1102",
#     "Begin_Code": "1715",
#     "Begin_Name": "花蓮",
#     "Begin_EName": "Hualien",
#     "End_Code": "1203",
#     "End_Name": "員林",
#     "End_EName": "Yuanlin",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "2",
#     "Handicapped": "Y",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "2035",
#     "To_Arrival_Time": "2130",
#     "Fare": 177,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1255",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1025",
#     "End_Name": "新竹",
#     "End_EName": "Hsinchu",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "0",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "2044",
#     "To_Arrival_Time": "2223",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "2273",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1120",
#     "End_Name": "彰化",
#     "End_EName": "Changhua",
#     "Over_Night": "1319",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "2054",
#     "To_Arrival_Time": "2231",
#     "Fare": 114,
#     "Comment": "每日行駛。在臺中跨日。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "155",
#     "Class_Code": "1108",
#     "Begin_Code": "1003",
#     "Begin_Name": "七堵",
#     "Begin_EName": "Qidu",
#     "End_Code": "1215",
#     "End_Name": "嘉義",
#     "End_EName": "Chiayi",
#     "Over_Night": "1210",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "Y",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "2100",
#     "To_Arrival_Time": "2208",
#     "Fare": 177,
#     "Comment": "每日行駛。在斗六跨日。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1261",
#     "Class_Code": "1131",
#     "Begin_Code": "1804",
#     "Begin_Name": "瑞芳",
#     "Begin_EName": "Ruifang",
#     "End_Code": "1025",
#     "End_Name": "新竹",
#     "End_EName": "Hsinchu",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "0",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "2109",
#     "To_Arrival_Time": "2243",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1263",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1305",
#     "End_Name": "苗栗",
#     "End_EName": "Miaoli",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "2129",
#     "To_Arrival_Time": "2301",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1273",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1305",
#     "End_Name": "苗栗",
#     "End_EName": "Miaoli",
#     "Over_Night": "1305",
#     "Direction": "1",
#     "MainViaRoad": "1",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "2157",
#     "To_Arrival_Time": "2327",
#     "Fare": 114,
#     "Comment": "每日行駛。在苗栗跨日。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1269",
#     "Class_Code": "1131",
#     "Begin_Code": "1810",
#     "Begin_Name": "福隆",
#     "Begin_EName": "Fulong",
#     "End_Code": "1025",
#     "End_Name": "新竹",
#     "End_EName": "Hsinchu",
#     "Over_Night": "0",
#     "Direction": "1",
#     "MainViaRoad": "0",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "2216",
#     "To_Arrival_Time": "2347",
#     "Fare": 114,
#     "Comment": "每日行駛。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   },
#   {
#     "Train_Code": "1281",
#     "Class_Code": "1131",
#     "Begin_Code": "1001",
#     "Begin_Name": "基隆",
#     "Begin_EName": "Keelung",
#     "End_Code": "1025",
#     "End_Name": "新竹",
#     "End_EName": "Hsinchu",
#     "Over_Night": "1020",
#     "Direction": "1",
#     "MainViaRoad": "0",
#     "Handicapped": "N",
#     "Package": "N",
#     "Dining": "N",
#     "TrainType": "0",
#     "From_Departure_Time": "2300",
#     "To_Arrival_Time": "0030",
#     "Fare": 114,
#     "Comment": "每日行駛。在富岡跨日。",
#     "Discount_Price_Adult": null,
#     "Discount_Begin_Date": null,
#     "Discount_End_Date": null,
#     "From_Ticket_Code": "100",
#     "To_Ticket_Code": "115",
#     "Everyday": "Y",
#     "TicketLink": "Y"
#   }
# ];</script>]
