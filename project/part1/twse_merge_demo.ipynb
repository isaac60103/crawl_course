# %%
#使用CSV
import pandas as pd

#讀取要合併的csv檔
csv1 = pd.read_csv('../data/fp_demo.csv')
csv2 = pd.read_csv('../data/fp_demo2.csv')

#以'日期'為index合併Dataframe
result = pd.merge(csv1, csv2, on='日期')
result.sort_index(ascending=False).head()
# Out:
#             日期        成交股數           成交金額    開盤價    最高價    最低價    收盤價  漲跌價差  \
# 40  2017/10/31  22,582,013  5,497,062,659  243.5  245.0  241.5  243.0   0.0
# 39  2017/10/30  30,241,990  7,358,619,170  242.0  245.0  241.5  243.0   4.0
# 38  2017/10/27  18,040,541  4,304,460,160  237.5  240.0  237.5  239.0   3.0
# 37  2017/10/26  12,959,717  3,069,618,429  237.0  238.0  236.0  236.0  -2.0
# 36  2017/10/25  17,205,187  4,099,505,436  238.5  239.0  237.5  238.0   0.0
#
#       成交筆數  美元／新台幣   人民幣／新台幣    歐元／美元    美元／日幣    英鎊／美元    澳幣／美元    美元／港幣  \
# 40   8,176  30.170  4.551175  1.16440  113.065  1.32145  0.76790  7.80160
# 39  10,609  30.205  4.542892  1.16270  113.700  1.31630  0.76745  7.79985
# 38   5,715  30.277  4.550936  1.16310  114.110  1.30750  0.76415  7.80370
# 37   4,947  30.229  4.554422  1.18175  113.760  1.32375  0.76870  7.80165
# 36   5,808  30.266  4.557152  1.17670  113.860  1.31320  0.77135  7.80330
#
#      美元／人民幣    美元／南非幣    紐幣／美元
# 40  6.62905  14.06155  0.68485
# ...

# %%
result.to_csv('../data/fp_demo3.csv', sep=',', encoding='utf-8-sig', index=False)

# %%
#使用SqLite
import pandas.io.sql as pd_sql
import sqlite3 as sql
import pandas as pd

#連線至sqlite檔案，若無該檔案sql，則會建立一個新的
conn = sql.connect("../data/twse.db")


df1 = pd.read_sql_query("select * from demo1;", conn)
df2 = pd.read_sql_query("select * from demo2;", conn)

#以'日期'為index合併Dataframe
result = pd.merge(df1, df2, on='日期')
#將result寫入sql檔中的'demo3'表中，無該資料表則會自動建立
result.to_sql("demo3", conn, if_exists="replace", index=False)

# %%
pd.read_sql_query("select * from demo3;", conn).sort_index(ascending=False).head()
# Out:
#             日期        成交股數           成交金額     開盤價     最高價     最低價     收盤價  \
# 40  2017/10/31  22,582,013  5,497,062,659  243.50  245.00  241.50  243.00
# 39  2017/10/30  30,241,990  7,358,619,170  242.00  245.00  241.50  243.00
# 38  2017/10/27  18,040,541  4,304,460,160  237.50  240.00  237.50  239.00
# 37  2017/10/26  12,959,717  3,069,618,429  237.00  238.00  236.00  236.00
# 36  2017/10/25  17,205,187  4,099,505,436  238.50  239.00  237.50  238.00
#
#      漲跌價差    成交筆數  美元／新台幣   人民幣／新台幣    歐元／美元    美元／日幣    英鎊／美元    澳幣／美元  \
# 40   0.00   8,176   30.17  4.551175   1.1644  113.065  1.32145   0.7679
# 39  +4.00  10,609  30.205  4.542892   1.1627    113.7   1.3163  0.76745
# 38  +3.00   5,715  30.277  4.550936   1.1631   114.11   1.3075  0.76415
# 37  -2.00   4,947  30.229  4.554422  1.18175   113.76  1.32375   0.7687
# 36   0.00   5,808  30.266  4.557152   1.1767   113.86   1.3132  0.77135
#
#       美元／港幣   美元／人民幣    美元／南非幣    紐幣／美元
# 40   7.8016  6.62905  14.06155  0.68485
# ...
